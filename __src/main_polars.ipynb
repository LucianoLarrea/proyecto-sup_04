# %%
from fastapi import FastAPI

app = FastAPI()

import polars as pl

df = pl.read_csv('../app/chocobar.csv', sep=',', infer_schema_length=10000)

df1 = df.filter(pl.col('cacao')=='100%')
dic1 = df1.to_dict()

sorted_df = df.sort(by='cacao', descending=True)
df2 = sorted_df.head(10)
dic2 = df2.to_dict()

df3 = df
dic3 = df3.to_dict()

mean_ref = df['ref'].mean()
df4 = df.filter(pl.col('ref')<mean_ref)
df4 = df4.select(pl.col(['company','ref','res']))
dic4 = df4.to_dict()


@app.get('/')
async def index():
    return{'estado','funcionando'}

@app.get('/puro')
async def puro():
    return dic1

@app.get('/top10')
async def top10():
    return dic2

@app.get('/full')
async def full():
    return dic3

@app.get('/ref')
async def ref():
    return dic4

# %%
dic1
# Out:
# {'company': shape: (20,)
#  Series: 'company' [str]
#  [
#  	"Artisan du Cho...
#  	"Bonnat"
#  	"Bouga Cacao (T...
#  	"C-Amaro"
#  	"Claudio Corall...
#  	"Coppeneur"
#  	"Domori"
#  	"Habitual"
#  	"Hotel Chocolat...
#  	"Hotel Chocolat...
#  	"Hotel Chocolat...
#  	"Hotel Chocolat...
#  	"Ocho"
#  	"Pacari"
#  	"Pralus"
#  	"S.A.I.D."
#  	"Sirene"
#  	"Sirene"
#  	"Vintage Planta...
#  	"Willie's Cacao...
#  ],
#  'name-origin': shape: (20,)
#  Series: 'name-origin' [str]
#  [
#  	"Venezuela"
#  	"One Hundred"
#  	"El Oro, Hacien...
#  	"Ecuador"
#  	"Principe"
#  	"Ecuador Purist...
#  	"IL100, H. San ...
#  	"one hundred"
#  	"Island Growers...
#  	"Chanchamayo, P...
#  	"Los Rios, H. I...
#  	"Conacado, 2012...
#  	"Sang Yum Coop"
#  	"Raw"
#  	"Sambirano Vall...
#  	"100 percent"
#  	"Somia Plantati...
#  	"Camino Verde P...
#  	"Los Rios, Ranc...
#  	"Java, Indonesi...
#  ],
#  'ref': shape: (20,)
#  Series: 'ref' [i64]
#  [
#  	486
#  	81
#  	341
#  	1185
#  	252
#  	817
#  	1109
#  	1205
#  	1113
#  	1109
#  	1113
#  	1113
#  	1760
#  	266
#  	202
#  	615
#  	1502
#  	1506
#  	153
#  	1109
#  ],
#  'review': shape: (20,)
#  Series: 'review' [i64]
#  [
#  	2010
#  	2006
#  	2009
#  	2013
#  	2008
#  	2012
#  	2013
#  	2014
#  	2013
#  	2013
#  	2013
#  	2013
#  	2016
#  	2008
#  	2008
#  	2010
#  	2015
#  	2015
#  	2007
#  	2013
#  ],
#  'cacao': shape: (20,)
#  Series: 'cacao' [str]
#  [
#  	"100%"
#  	"100%"
#  	"100%"
#  	"100%"
#  	"100%"
#  	"100%"
#  	"100%"
#  	"100%"
#  	"100%"
#  	"100%"
#  	"100%"
#  	"100%"
#  	"100%"
#  	"100%"
#  	"100%"
#  	"100%"
#  	"100%"
#  	"100%"
#  	"100%"
#  	"100%"
#  ],
#  'location': shape: (20,)
#  Series: 'location' [str]
#  [
#  	"U.K."
#  	"France"
#  	"Ecuador"
#  	"Italy"
#  	"Sao Tome"
#  	"Germany"
#  	"Italy"
#  	"Canada"
#  	"U.K."
#  	"U.K."
#  	"U.K."
#  	"U.K."
#  	"New Zealand"
#  	"Ecuador"
#  	"France"
#  	"Italy"
#  	"Canada"
#  	"Canada"
#  	"U.S.A."
#  	"U.K."
#  ],
#  'rating': shape: (20,)
#  Series: 'rating' [f64]
#  [
#  	1.75
#  	1.5
#  	1.5
#  	3.5
#  	1.0
#  	1.5
#  	3.0
#  	2.0
#  	1.75
#  	2.75
#  	2.5
#  	2.75
#  	2.75
#  	2.0
#  	3.0
#  	1.5
#  	3.0
#  	3.0
#  	2.0
#  	2.25
#  ],
#  'bean': shape: (20,)
#  Series: 'bean' [str]
#  [
#  	" "
#  	" "
#  	"Forastero (Arr...
#  	" "
#  	"Forastero"
#  	" "
#  	"Criollo"
#  	" "
#  	"Trinitario"
#  	" "
#  	"Forastero (Nac...
#  	" "
#  	" "
#  	"Forastero (Arr...
#  	"Criollo"
#  	" "
#  	"Trinitario"
#  	" "
#  	"Forastero (Arr...
#  	" "
#  ],
#  'bean-origin': shape: (20,)
#  Series: 'bean-origin' [str]
#  [
#  	"Venezuela"
#  	" "
#  	"Ecuador"
#  	"Ecuador"
#  	"Sao Tome & Pri...
#  	"Ecuador"
#  	"Venezuela"
#  	" "
#  	"St. Lucia"
#  	"Peru"
#  	"Ecuador"
#  	"Dominican Repu...
#  	"Samoa"
#  	"Ecuador"
#  	"Madagascar"
#  	" "
#  	"Madagascar"
#  	"Ecuador"
#  	"Ecuador"
#  	"Indonesia"
#  ],
#  'pur': shape: (20,)
#  Series: 'pur' [str]
#  [
#  	"PURO"
#  	"PURO"
#  	"PURO"
#  	"PURO"
#  	"PURO"
#  	"PURO"
#  	"PURO"
#  	"PURO"
#  	"PURO"
#  	"PURO"
#  	"PURO"
#  	"PURO"
#  	"PURO"
#  	"PURO"
#  	"PURO"
#  	"PURO"
#  	"PURO"
#  	"PURO"
#  	"PURO"
#  	"PURO"
#  ],
#  'res': shape: (20,)
#  Series: 'res' [str]
#  [
#  	"Artisan du Cho...
#  	"Bonnat&PURO&1....
#  	"Bouga Cacao (T...
#  	"C-Amaro&PURO&3...
#  	"Claudio Corall...
#  	"Coppeneur&PURO...
#  	"Domori&PURO&3....
#  	"Habitual&PURO&...
#  	"Hotel Chocolat...
#  	"Hotel Chocolat...
#  	"Hotel Chocolat...
#  	"Hotel Chocolat...
#  	"Ocho&PURO&2.75...
#  	"Pacari&PURO&2....
#  	"Pralus&PURO&3....
#  	"S.A.I.D.&PURO&...
#  	"Sirene&PURO&3....
#  	"Sirene&PURO&3....
#  	"Vintage Planta...
#  	"Willie's Cacao...
#  ]}
